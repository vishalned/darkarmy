# %%
# %cd drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# %cd darkarmy/
# Out:
# /content/drive/MyDrive/darkarmy

# %%
# !pip install "git+https://github.com/deepset-ai/FARM.git@0749dcb8fb46dace0d0987d6fdedf5f28120a461"
# !pip install "git+https://github.com/deepset-ai/haystack.git@0cffc6cb1df8782bbf1bbc336807de355687584b"
# !pip install ipywidgets
# Out:
# Collecting git+https://github.com/deepset-ai/FARM.git@0749dcb8fb46dace0d0987d6fdedf5f28120a461
#   Cloning https://github.com/deepset-ai/FARM.git (to revision 0749dcb8fb46dace0d0987d6fdedf5f28120a461) to /tmp/pip-req-build-6t6sp8_s
#   Running command git clone -q https://github.com/deepset-ai/FARM.git /tmp/pip-req-build-6t6sp8_s
#   Running command git rev-parse -q --verify 'sha^0749dcb8fb46dace0d0987d6fdedf5f28120a461'
#   Running command git fetch -q https://github.com/deepset-ai/FARM.git 0749dcb8fb46dace0d0987d6fdedf5f28120a461
#   Running command git checkout -q 0749dcb8fb46dace0d0987d6fdedf5f28120a461
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from farm==0.4.2) (57.4.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from farm==0.4.2) (0.37.0)
# Requirement already satisfied: torch>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from farm==0.4.2) (1.9.0+cu102)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from farm==0.4.2) (4.62.0)
# Collecting boto3
#   Downloading boto3-1.18.31-py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 9.4 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from farm==0.4.2) (2.23.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from farm==0.4.2) (1.4.1)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from farm==0.4.2) (0.0)
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      |████████████████████████████████| 43 kB 2.1 MB/s
# Collecting mlflow==1.0.0
#   Downloading mlflow-1.0.0-py3-none-any.whl (47.7 MB)
#      |████████████████████████████████| 47.7 MB 36 kB/s
# Collecting transformers==2.7.0
#   Downloading transformers-2.7.0-py3-none-any.whl (544 kB)
#      |████████████████████████████████| 544 kB 42.7 MB/s
# Collecting dotmap==1.3.0
#   Using cached dotmap-1.3.0-py3-none-any.whl (8.9 kB)
# Collecting Werkzeug==0.16.1
#   Downloading Werkzeug-0.16.1-py2.py3-none-any.whl (327 kB)
#      |████████████████████████████████| 327 kB 37.9 MB/s
# Requirement already satisfied: flask in /usr/local/lib/python3.7/dist-packages (from farm==0.4.2) (1.1.4)
# Collecting flask-restplus
#   Downloading flask_restplus-0.13.0-py2.py3-none-any.whl (2.5 MB)
#      |████████████████████████████████| 2.5 MB 40.3 MB/s
# Collecting flask-cors
#   Downloading Flask_Cors-3.0.10-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from farm==0.4.2) (0.3.4)
# Collecting onnxruntime
#   Downloading onnxruntime-1.8.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#      |████████████████████████████████| 4.5 MB 43.6 MB/s
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm==0.4.2) (2.8.2)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm==0.4.2) (1.15.0)
# Collecting querystring-parser
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm==0.4.2) (3.17.3)
# Collecting alembic
#   Using cached alembic-1.6.5-py2.py3-none-any.whl (164 kB)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm==0.4.2) (1.4.22)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm==0.4.2) (3.13)
# Collecting gunicorn
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 8.5 MB/s
# Collecting databricks-cli>=0.8.0
#   Using cached databricks-cli-0.15.0.tar.gz (56 kB)
# Collecting docker>=3.6.0
#   Using cached docker-5.0.0-py2.py3-none-any.whl (146 kB)
# Requirement already satisfied: sqlparse in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm==0.4.2) (0.4.1)
# Collecting simplejson
#   Downloading simplejson-3.17.5-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (129 kB)
#      |████████████████████████████████| 129 kB 59.5 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm==0.4.2) (1.19.5)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm==0.4.2) (7.1.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm==0.4.2) (1.1.5)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm==0.4.2) (0.3)
# Collecting gitpython>=2.1.0
#   Downloading GitPython-3.1.18-py3-none-any.whl (170 kB)
#      |████████████████████████████████| 170 kB 72.4 MB/s
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm==0.4.2) (1.3.0)
# Collecting tokenizers==0.5.2
#   Downloading tokenizers-0.5.2-cp37-cp37m-manylinux1_x86_64.whl (5.6 MB)
#      |████████████████████████████████| 5.6 MB 14.3 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.45-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 35.7 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==2.7.0->farm==0.4.2) (2019.12.20)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 49.7 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==2.7.0->farm==0.4.2) (3.0.12)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.7/dist-packages (from databricks-cli>=0.8.0->mlflow==1.0.0->farm==0.4.2) (0.8.9)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.2.1-py2.py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 1.3 MB/s
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.7-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.4 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.0 in /usr/local/lib/python3.7/dist-packages (from gitpython>=2.1.0->mlflow==1.0.0->farm==0.4.2) (3.7.4.3)
# Collecting smmap<5,>=3.0.1
#   Downloading smmap-4.0.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->farm==0.4.2) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->farm==0.4.2) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->farm==0.4.2) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->farm==0.4.2) (2.10)
# Collecting Mako
#   Downloading Mako-1.1.5-py2.py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 4.7 MB/s
# Collecting python-editor>=0.3
#   Downloading python_editor-1.0.4-py3-none-any.whl (4.9 kB)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from sqlalchemy->mlflow==1.0.0->farm==0.4.2) (4.6.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy->mlflow==1.0.0->farm==0.4.2) (1.1.1)
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 8.0 MB/s
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting botocore<1.22.0,>=1.21.31
#   Downloading botocore-1.21.31-py3-none-any.whl (7.8 MB)
#      |████████████████████████████████| 7.8 MB 39.1 MB/s
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 78.5 MB/s
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from flask->farm==0.4.2) (2.11.3)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from flask->farm==0.4.2) (1.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->flask->farm==0.4.2) (2.0.1)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from flask-restplus->farm==0.4.2) (2018.9)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from flask-restplus->farm==0.4.2) (2.6.0)
# Collecting aniso8601>=0.82
#   Using cached aniso8601-9.0.1-py2.py3-none-any.whl (52 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy->mlflow==1.0.0->farm==0.4.2) (3.5.0)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.7/dist-packages (from onnxruntime->farm==0.4.2) (1.12)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==2.7.0->farm==0.4.2) (1.0.1)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.7/dist-packages (from seqeval->farm==0.4.2) (0.22.2.post1)
# Building wheels for collected packages: farm, databricks-cli, seqeval
#   Building wheel for farm (setup.py) ... done
#   Created wheel for farm: filename=farm-0.4.2-py3-none-any.whl size=132419 sha256=c887bc8accac777fe847bc64cb139418775c3a58eae12a362da565f206bd65ec
#   Stored in directory: /root/.cache/pip/wheels/ab/c6/07/8a6d54e8a1e32ffd4bde9e3b60194b023f6b2dc6fd09c16988
#   Building wheel for databricks-cli (setup.py) ... done
#   Created wheel for databricks-cli: filename=databricks_cli-0.15.0-py3-none-any.whl size=105260 sha256=34684323e953b8077d522d6ae4f2b88a118ab3f7ac1bb8a85ef92ea53d4ece95
#   Stored in directory: /root/.cache/pip/wheels/e7/ba/75/284f9a90ff7a010bb23b9798f2e9a19dd9fe619379c917bff4
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16181 sha256=c982251cdf18e030a8789dad7b33304a16523599a96df0767584af08e1007351
#   Stored in directory: /root/.cache/pip/wheels/05/96/ee/7cac4e74f3b19e3158dce26a20a1c86b3533c43ec72a549fd7
# Successfully built farm databricks-cli seqeval
# Installing collected packages: urllib3, jmespath, smmap, botocore, Werkzeug, websocket-client, s3transfer, python-editor, Mako, gitdb, tokenizers, simplejson, sentencepiece, sacremoses, querystring-parser, gunicorn, gitpython, docker, databricks-cli, boto3, aniso8601, alembic, transformers, seqeval, onnxruntime, mlflow, flask-restplus, flask-cors, dotmap, farm
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 1.0.1
#     Uninstalling Werkzeug-1.0.1:
#       Successfully uninstalled Werkzeug-1.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed Mako-1.1.5 Werkzeug-0.16.1 alembic-1.6.5 aniso8601-9.0.1 boto3-1.18.31 botocore-1.21.31 databricks-cli-0.15.0 docker-5.0.0 dotmap-1.3.0 farm-0.4.2 flask-cors-3.0.10 flask-restplus-0.13.0 gitdb-4.0.7 gitpython-3.1.18 gunicorn-20.1.0 jmespath-0.10.0 mlflow-1.0.0 onnxruntime-1.8.1 python-editor-1.0.4 querystring-parser-1.2.4 s3transfer-0.5.0 sacremoses-0.0.45 sentencepiece-0.1.96 seqeval-1.2.2 simplejson-3.17.5 smmap-4.0.0 tokenizers-0.5.2 transformers-2.7.0 urllib3-1.25.11 websocket-client-1.2.1
# Collecting git+https://github.com/deepset-ai/haystack.git@0cffc6cb1df8782bbf1bbc336807de355687584b
#   Cloning https://github.com/deepset-ai/haystack.git (to revision 0cffc6cb1df8782bbf1bbc336807de355687584b) to /tmp/pip-req-build-l85sn0qo
#   Running command git clone -q https://github.com/deepset-ai/haystack.git /tmp/pip-req-build-l85sn0qo
#   Running command git rev-parse -q --verify 'sha^0cffc6cb1df8782bbf1bbc336807de355687584b'
#   Running command git fetch -q https://github.com/deepset-ai/haystack.git 0cffc6cb1df8782bbf1bbc336807de355687584b
#   Running command git checkout -q 0cffc6cb1df8782bbf1bbc336807de355687584b
# Collecting farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm
#   Cloning https://github.com/deepset-ai/FARM.git (to revision 5d78cbe6293da616f7285ba2d3588efe5d5b453a) to /tmp/pip-install-aph7qtoi/farm_b0589f446bdb4447b69019e3816c3ee0
#   Running command git clone -q https://github.com/deepset-ai/FARM.git /tmp/pip-install-aph7qtoi/farm_b0589f446bdb4447b69019e3816c3ee0
#   Running command git rev-parse -q --verify 'sha^5d78cbe6293da616f7285ba2d3588efe5d5b453a'
#   Running command git fetch -q https://github.com/deepset-ai/FARM.git 5d78cbe6293da616f7285ba2d3588efe5d5b453a
#   Running command git checkout -q 5d78cbe6293da616f7285ba2d3588efe5d5b453a
# Collecting fastapi
#   Downloading fastapi-0.68.1-py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 829 kB/s
# Collecting uvicorn
#   Downloading uvicorn-0.15.0-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 2.9 MB/s
# Collecting flask_sqlalchemy
#   Downloading Flask_SQLAlchemy-2.5.1-py2.py3-none-any.whl (17 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from farm-haystack==0.1.3) (1.1.5)
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 20.1 MB/s
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from farm-haystack==0.1.3) (0.0)
# Collecting elasticsearch
#   Using cached elasticsearch-7.14.0-py2.py3-none-any.whl (364 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (57.4.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (0.37.0)
# Requirement already satisfied: torch>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (1.9.0+cu102)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (4.62.0)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.7/dist-packages (from farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (1.18.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (2.23.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (1.4.1)
# Requirement already satisfied: seqeval in /usr/local/lib/python3.7/dist-packages (from farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (1.2.2)
# Requirement already satisfied: mlflow==1.0.0 in /usr/local/lib/python3.7/dist-packages (from farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (1.0.0)
# Collecting transformers==2.4.0
#   Downloading transformers-2.4.0-py3-none-any.whl (475 kB)
#      |████████████████████████████████| 475 kB 59.2 MB/s
# Requirement already satisfied: dotmap==1.3.0 in /usr/local/lib/python3.7/dist-packages (from farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (1.3.0)
# Requirement already satisfied: Werkzeug==0.16.1 in /usr/local/lib/python3.7/dist-packages (from farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (0.16.1)
# Requirement already satisfied: flask in /usr/local/lib/python3.7/dist-packages (from farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (1.1.4)
# Requirement already satisfied: flask-restplus in /usr/local/lib/python3.7/dist-packages (from farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (0.13.0)
# Requirement already satisfied: flask-cors in /usr/local/lib/python3.7/dist-packages (from farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (3.0.10)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (0.3.4)
# Requirement already satisfied: alembic in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (1.6.5)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (1.15.0)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (1.4.22)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (0.3)
# Requirement already satisfied: databricks-cli>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (0.15.0)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (3.17.3)
# Requirement already satisfied: sqlparse in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (0.4.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (3.13)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (1.19.5)
# Requirement already satisfied: gitpython>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (3.1.18)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (1.3.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (2.8.2)
# Requirement already satisfied: docker>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (5.0.0)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (3.17.5)
# Requirement already satisfied: gunicorn in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (20.1.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (7.1.2)
# Requirement already satisfied: querystring-parser in /usr/local/lib/python3.7/dist-packages (from mlflow==1.0.0->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (1.2.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==2.4.0->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (2019.12.20)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers==2.4.0->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (0.0.45)
# Collecting tokenizers==0.0.11
#   Downloading tokenizers-0.0.11-cp37-cp37m-manylinux1_x86_64.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 46.7 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==2.4.0->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (3.0.12)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from transformers==2.4.0->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (0.1.96)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.7/dist-packages (from databricks-cli>=0.8.0->mlflow==1.0.0->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (0.8.9)
# Requirement already satisfied: websocket-client>=0.32.0 in /usr/local/lib/python3.7/dist-packages (from docker>=3.6.0->mlflow==1.0.0->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (1.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.0 in /usr/local/lib/python3.7/dist-packages (from gitpython>=2.1.0->mlflow==1.0.0->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (3.7.4.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from gitpython>=2.1.0->mlflow==1.0.0->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from gitdb<5,>=4.0.1->gitpython>=2.1.0->mlflow==1.0.0->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (2.10)
# Requirement already satisfied: Mako in /usr/local/lib/python3.7/dist-packages (from alembic->mlflow==1.0.0->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (1.1.5)
# Requirement already satisfied: python-editor>=0.3 in /usr/local/lib/python3.7/dist-packages (from alembic->mlflow==1.0.0->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (1.0.4)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from sqlalchemy->mlflow==1.0.0->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (4.6.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy->mlflow==1.0.0->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (1.1.1)
# Requirement already satisfied: botocore<1.22.0,>=1.21.31 in /usr/local/lib/python3.7/dist-packages (from boto3->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (1.21.31)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from boto3->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (0.5.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from boto3->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (0.10.0)
# Collecting pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2
#   Downloading pydantic-1.8.2-cp37-cp37m-manylinux2014_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 35.1 MB/s
# Collecting starlette==0.14.2
#   Downloading starlette-0.14.2-py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 7.4 MB/s
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from flask->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (2.11.3)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from flask->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (1.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->flask->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (2.0.1)
# Requirement already satisfied: aniso8601>=0.82 in /usr/local/lib/python3.7/dist-packages (from flask-restplus->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (9.0.1)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from flask-restplus->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (2.6.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from flask-restplus->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (2018.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy->mlflow==1.0.0->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (3.5.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==2.4.0->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (1.0.1)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.7/dist-packages (from seqeval->farm@ git+https://github.com/deepset-ai/FARM.git@5d78cbe6293da616f7285ba2d3588efe5d5b453a#egg=farm@v2.4.1#egg=farm->farm-haystack==0.1.3) (0.22.2.post1)
# Collecting asgiref>=3.4.0
#   Using cached asgiref-3.4.1-py3-none-any.whl (25 kB)
# Collecting h11>=0.8
#   Downloading h11-0.12.0-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 2.4 MB/s
# Building wheels for collected packages: farm-haystack, farm
#   Building wheel for farm-haystack (setup.py) ... done
#   Created wheel for farm-haystack: filename=farm_haystack-0.1.3-py3-none-any.whl size=29919 sha256=11dacfed12436c7eb1d9ffb689afd551037a528318ef2d58df27e5ba0565b97b
#   Stored in directory: /root/.cache/pip/wheels/12/24/1a/924f8b6d170c42af7e8fa4ccf91cb3a1e55b7bd0e947e1d50b
#   Building wheel for farm (setup.py) ... done
#   Created wheel for farm: filename=farm-0.4.1-py3-none-any.whl size=127353 sha256=c40c3e3ae0df35defaa8acbf7df5da822694c8959331813e4846261e6d67c629
#   Stored in directory: /root/.cache/pip/wheels/92/64/bc/11ed4631612f8e410699829d9fa6bc9347db92a17ffe8e5f8a
# Successfully built farm-haystack farm
# Installing collected packages: tokenizers, transformers, starlette, pydantic, h11, asgiref, uvicorn, psycopg2-binary, flask-sqlalchemy, fastapi, farm, elasticsearch, farm-haystack
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.5.2
#     Uninstalling tokenizers-0.5.2:
#       Successfully uninstalled tokenizers-0.5.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 2.7.0
#     Uninstalling transformers-2.7.0:
#       Successfully uninstalled transformers-2.7.0
#   Attempting uninstall: farm
#     Found existing installation: farm 0.4.2
#     Uninstalling farm-0.4.2:
#       Successfully uninstalled farm-0.4.2
# Successfully installed asgiref-3.4.1 elasticsearch-7.14.0 farm-0.4.1 farm-haystack-0.1.3 fastapi-0.68.1 flask-sqlalchemy-2.5.1 h11-0.12.0 psycopg2-binary-2.9.1 pydantic-1.8.2 starlette-0.14.2 tokenizers-0.0.11 transformers-2.4.0 uvicorn-0.15.0
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.7/dist-packages (7.6.3)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets) (5.5.0)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets) (5.1.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets) (1.0.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets) (4.10.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets) (3.5.1)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets) (5.0.5)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets) (5.1.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets) (5.3.5)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets) (4.4.2)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets) (1.0.18)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets) (4.8.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets) (2.6.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets) (57.4.0)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets) (0.8.1)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets) (4.7.1)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets) (2.6.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0->ipywidgets) (1.15.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.5.0->ipywidgets) (5.3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.11.3)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.11.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (5.6.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.8.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets) (22.2.1)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.0.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.4.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (4.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.7.1)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.4.7)

# %%
# !pip install streamlit
# !pip install bokeh
# !pip install streamlit-bokeh-events
# Out:
# Requirement already satisfied: streamlit in /usr/local/lib/python3.7/dist-packages (0.87.0)
# Requirement already satisfied: pydeck>=0.1.dev5 in /usr/local/lib/python3.7/dist-packages (from streamlit) (0.7.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from streamlit) (21.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from streamlit) (2.23.0)
# Requirement already satisfied: watchdog in /usr/local/lib/python3.7/dist-packages (from streamlit) (2.1.5)
# Requirement already satisfied: base58 in /usr/local/lib/python3.7/dist-packages (from streamlit) (2.1.0)
# Requirement already satisfied: blinker in /usr/local/lib/python3.7/dist-packages (from streamlit) (1.4)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.7/dist-packages (from streamlit) (1.5.1)
# Requirement already satisfied: click<8.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from streamlit) (7.1.2)
# Requirement already satisfied: gitpython!=3.1.19 in /usr/local/lib/python3.7/dist-packages (from streamlit) (3.1.18)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.7/dist-packages (from streamlit) (3.0.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from streamlit) (7.1.2)
# Requirement already satisfied: tornado>=5.0 in /usr/local/lib/python3.7/dist-packages (from streamlit) (5.1.1)
# Requirement already satisfied: cachetools>=4.0 in /usr/local/lib/python3.7/dist-packages (from streamlit) (4.2.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from streamlit) (21.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from streamlit) (2.8.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from streamlit) (1.19.5)
# Requirement already satisfied: protobuf!=3.11,>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from streamlit) (3.17.3)
# Requirement already satisfied: pandas>=0.21.0 in /usr/local/lib/python3.7/dist-packages (from streamlit) (1.1.5)
# Requirement already satisfied: validators in /usr/local/lib/python3.7/dist-packages (from streamlit) (0.18.2)
# Requirement already satisfied: astor in /usr/local/lib/python3.7/dist-packages (from streamlit) (0.8.1)
# Requirement already satisfied: altair>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from streamlit) (4.1.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit) (2.6.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit) (2.11.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit) (0.3)
# Requirement already satisfied: toolz in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit) (0.11.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from gitpython!=3.1.19->streamlit) (4.0.7)
# Requirement already satisfied: typing-extensions>=3.7.4.0 in /usr/local/lib/python3.7/dist-packages (from gitpython!=3.1.19->streamlit) (3.7.4.3)
# Requirement already satisfied: smmap<5,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit) (4.0.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21.0->streamlit) (2018.9)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf!=3.11,>=3.6.0->streamlit) (1.15.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.7/dist-packages (from pydeck>=0.1.dev5->streamlit) (7.6.3)
# Requirement already satisfied: traitlets>=4.3.2 in /usr/local/lib/python3.7/dist-packages (from pydeck>=0.1.dev5->streamlit) (5.0.5)
# Requirement already satisfied: ipykernel>=5.1.2 in /usr/local/lib/python3.7/dist-packages (from pydeck>=0.1.dev5->streamlit) (6.2.0)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (1.0.0)
# Requirement already satisfied: argcomplete>=1.12.3 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (1.12.3)
# Requirement already satisfied: ipython<8.0,>=7.23.1 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (7.27.0)
# Requirement already satisfied: importlib-metadata<5 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (4.6.4)
# Requirement already satisfied: jupyter-client<8.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (5.3.5)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata<5->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (3.5.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (57.4.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (2.6.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (3.0.20)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.18.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (4.4.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.1.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.16->ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.8.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->altair>=3.2.0->streamlit) (2.0.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (4.7.1)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (22.2.1)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect>4.3->ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.3.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.6.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.8.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.11.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.8.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (4.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.7.1)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.4.3)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->streamlit) (2.4.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->streamlit) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->streamlit) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->streamlit) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->streamlit) (1.25.11)
# Requirement already satisfied: bokeh in /usr/local/lib/python3.7/dist-packages (2.3.3)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.7/dist-packages (from bokeh) (2.11.3)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.7/dist-packages (from bokeh) (3.13)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.7/dist-packages (from bokeh) (7.1.2)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from bokeh) (3.7.4.3)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.7/dist-packages (from bokeh) (1.19.5)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.7/dist-packages (from bokeh) (21.0)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.7/dist-packages (from bokeh) (5.1.1)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from bokeh) (2.8.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2>=2.9->bokeh) (2.0.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=16.8->bokeh) (2.4.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.1->bokeh) (1.15.0)
# Collecting streamlit-bokeh-events
#   Downloading streamlit_bokeh_events-0.1.2-py3-none-any.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 8.2 MB/s
# Requirement already satisfied: bokeh>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from streamlit-bokeh-events) (2.3.3)
# Requirement already satisfied: streamlit>=0.63 in /usr/local/lib/python3.7/dist-packages (from streamlit-bokeh-events) (0.87.0)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.7/dist-packages (from bokeh>=2.0.0->streamlit-bokeh-events) (1.19.5)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from bokeh>=2.0.0->streamlit-bokeh-events) (3.7.4.3)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from bokeh>=2.0.0->streamlit-bokeh-events) (2.8.2)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.7/dist-packages (from bokeh>=2.0.0->streamlit-bokeh-events) (7.1.2)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.7/dist-packages (from bokeh>=2.0.0->streamlit-bokeh-events) (5.1.1)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.7/dist-packages (from bokeh>=2.0.0->streamlit-bokeh-events) (3.13)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.7/dist-packages (from bokeh>=2.0.0->streamlit-bokeh-events) (2.11.3)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.7/dist-packages (from bokeh>=2.0.0->streamlit-bokeh-events) (21.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2>=2.9->bokeh>=2.0.0->streamlit-bokeh-events) (2.0.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=16.8->bokeh>=2.0.0->streamlit-bokeh-events) (2.4.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.1->bokeh>=2.0.0->streamlit-bokeh-events) (1.15.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from streamlit>=0.63->streamlit-bokeh-events) (0.10.2)
# Requirement already satisfied: cachetools>=4.0 in /usr/local/lib/python3.7/dist-packages (from streamlit>=0.63->streamlit-bokeh-events) (4.2.2)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from streamlit>=0.63->streamlit-bokeh-events) (21.2.0)
# Requirement already satisfied: pydeck>=0.1.dev5 in /usr/local/lib/python3.7/dist-packages (from streamlit>=0.63->streamlit-bokeh-events) (0.7.0)
# Requirement already satisfied: click<8.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from streamlit>=0.63->streamlit-bokeh-events) (7.1.2)
# Requirement already satisfied: pandas>=0.21.0 in /usr/local/lib/python3.7/dist-packages (from streamlit>=0.63->streamlit-bokeh-events) (1.1.5)
# Requirement already satisfied: base58 in /usr/local/lib/python3.7/dist-packages (from streamlit>=0.63->streamlit-bokeh-events) (2.1.0)
# Requirement already satisfied: protobuf!=3.11,>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from streamlit>=0.63->streamlit-bokeh-events) (3.17.3)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.7/dist-packages (from streamlit>=0.63->streamlit-bokeh-events) (1.5.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from streamlit>=0.63->streamlit-bokeh-events) (2.23.0)
# Requirement already satisfied: altair>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from streamlit>=0.63->streamlit-bokeh-events) (4.1.0)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.7/dist-packages (from streamlit>=0.63->streamlit-bokeh-events) (3.0.0)
# Requirement already satisfied: validators in /usr/local/lib/python3.7/dist-packages (from streamlit>=0.63->streamlit-bokeh-events) (0.18.2)
# Requirement already satisfied: astor in /usr/local/lib/python3.7/dist-packages (from streamlit>=0.63->streamlit-bokeh-events) (0.8.1)
# Requirement already satisfied: gitpython!=3.1.19 in /usr/local/lib/python3.7/dist-packages (from streamlit>=0.63->streamlit-bokeh-events) (3.1.18)
# Requirement already satisfied: blinker in /usr/local/lib/python3.7/dist-packages (from streamlit>=0.63->streamlit-bokeh-events) (1.4)
# Requirement already satisfied: watchdog in /usr/local/lib/python3.7/dist-packages (from streamlit>=0.63->streamlit-bokeh-events) (2.1.5)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit>=0.63->streamlit-bokeh-events) (0.3)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit>=0.63->streamlit-bokeh-events) (2.6.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit>=0.63->streamlit-bokeh-events) (0.11.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from gitpython!=3.1.19->streamlit>=0.63->streamlit-bokeh-events) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit>=0.63->streamlit-bokeh-events) (4.0.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21.0->streamlit>=0.63->streamlit-bokeh-events) (2018.9)
# Requirement already satisfied: ipykernel>=5.1.2 in /usr/local/lib/python3.7/dist-packages (from pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (6.2.0)
# Requirement already satisfied: traitlets>=4.3.2 in /usr/local/lib/python3.7/dist-packages (from pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (5.0.5)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.7/dist-packages (from pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (7.6.3)
# Requirement already satisfied: ipython<8.0,>=7.23.1 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (7.27.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (1.0.0)
# Requirement already satisfied: importlib-metadata<5 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (4.6.4)
# Requirement already satisfied: jupyter-client<8.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (5.3.5)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (0.1.2)
# Requirement already satisfied: argcomplete>=1.12.3 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (1.12.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata<5->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (3.5.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (0.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (3.0.20)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (0.7.5)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (2.6.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (57.4.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (4.4.2)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (5.1.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (3.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.16->ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (0.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (4.7.1)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (22.2.1)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (0.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect>4.3->ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (5.3.1)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (0.11.0)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (1.8.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (5.6.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (0.8.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (4.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (0.7.1)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (0.5.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (1.4.3)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-bokeh-events) (0.5.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->streamlit>=0.63->streamlit-bokeh-events) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->streamlit>=0.63->streamlit-bokeh-events) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->streamlit>=0.63->streamlit-bokeh-events) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->streamlit>=0.63->streamlit-bokeh-events) (2.10)
# Installing collected packages: streamlit-bokeh-events
# Successfully installed streamlit-bokeh-events-0.1.2

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Out:
# --2021-08-28 08:57:11--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 34.203.159.69, 3.228.156.171, 35.153.95.212, ...
# Connecting to bin.equinox.io (bin.equinox.io)|34.203.159.69|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13832437 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  13.19M  15.9MB/s    in 0.8s
#
# 2021-08-28 08:57:12 (15.9 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [13832437/13832437]

# %%
# !unzip ngrok-stable-linux-amd64.zip
# Out:
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok

# %%
get_ipython().system_raw('./ngrok http 8501 &')

# %%
# !curl -s http://localhost:4040/api/tunnels | python3 -c \
    'import sys, json; print("Execute the next cell and the go to the following URL: " +json.load(sys.stdin)["tunnels"][0]["public_url"])'
# Out:
# Execute the next cell and the go to the following URL: https://0a03-35-203-168-230.ngrok.io

# %%
# !streamlit run main.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.2:8501
#   External URL: http://35.203.168.230:8501
#
# /usr/local/lib/python3.7/dist-packages/haystack/database/sql.py:102: SAWarning: relationship 'Document.Tag' will copy column document.id to column document_tag.document_id, which conflicts with relationship(s): 'Document.tags' (copies document.id to document_tag.document_id), 'Tag.Document' (copies document.id to document_tag.document_id). If this is not the intention, consider if these relationships should be linked with back_populates, or if viewonly=True should be applied to one or more if they are read-only. For the less common case that foreign key constraints are partially overlapping, the orm.foreign() annotation can be used to isolate the columns that should be written towards.   To silence this warning, add the parameter 'overlaps="Document,tags"' to the 'Document.Tag' relationship.
#   return self.session.query(Document).count()
# /usr/local/lib/python3.7/dist-packages/haystack/database/sql.py:102: SAWarning: relationship 'Document.Tag' will copy column tag.id to column document_tag.tag_id, which conflicts with relationship(s): 'Document.tags' (copies tag.id to document_tag.tag_id), 'Tag.Document' (copies tag.id to document_tag.tag_id). If this is not the intention, consider if these relationships should be linked with back_populates, or if viewonly=True should be applied to one or more if they are read-only. For the less common case that foreign key constraints are partially overlapping, the orm.foreign() annotation can be used to isolate the columns that should be written towards.   To silence this warning, add the parameter 'overlaps="Document,tags"' to the 'Document.Tag' relationship.
#   return self.session.query(Document).count()
# /usr/local/lib/python3.7/dist-packages/haystack/database/sql.py:102: SAWarning: relationship 'Tag.documents' will copy column tag.id to column document_tag.tag_id, which conflicts with relationship(s): 'Document.tags' (copies tag.id to document_tag.tag_id), 'Tag.Document' (copies tag.id to document_tag.tag_id). If this is not the intention, consider if these relationships should be linked with back_populates, or if viewonly=True should be applied to one or more if they are read-only. For the less common case that foreign key constraints are partially overlapping, the orm.foreign() annotation can be used to isolate the columns that should be written towards.   To silence this warning, add the parameter 'overlaps="Document,tags"' to the 'Tag.documents' relationship.
#   return self.session.query(Document).count()
# /usr/local/lib/python3.7/dist-packages/haystack/database/sql.py:102: SAWarning: relationship 'Tag.documents' will copy column document.id to column document_tag.document_id, which conflicts with relationship(s): 'Document.tags' (copies document.id to document_tag.document_id), 'Tag.Document' (copies document.id to document_tag.document_id). If this is not the intention, consider if these relationships should be linked with back_populates, or if viewonly=True should be applied to one or more if they are read-only. For the less common case that foreign key constraints are partially overlapping, the orm.foreign() annotation can be used to isolate the columns that should be written towards.   To silence this warning, add the parameter 'overlaps="Document,tags"' to the 'Tag.documents' relationship.
#   return self.session.query(Document).count()
# 370
# Skip writing documents since DB already contains 370 docs ...  (Disable `only_empty_db`, if you want to add docs anyway.)
# 2021-08-28 08:57:57.366 device: cpu n_gpu: 0, distributed training: False, automatic mixed precision training: None
# 2021-08-28 08:57:57.366 Could not find `deepset/bert-large-uncased-whole-word-masking-squad2` locally. Try to download from model hub ...
# 2021-08-28 08:58:04.667 Could not automatically detect from language model name what language it is.
# 	 We guess it's an *ENGLISH* model ...
# 	 If not: Init the language model by supplying the 'language' param.
# 2021-08-28 08:58:14.457 Some unused parameters are passed to the QuestionAnsweringHead. Might not be a problem. Params: {"loss_ignore_index": -1}
# 2021-08-28 08:58:16.937 device: cpu n_gpu: 0, distributed training: False, automatic mixed precision training: None
# Inferencing Samples:   0% 0/10 [00:00<?, ? Batches/s]/usr/local/lib/python3.7/dist-packages/torch/_tensor.py:575: UserWarning: floor_divide is deprecated, and will be removed in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values.
# To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor'). (Triggered internally at  /pytorch/aten/src/ATen/native/BinaryOps.cpp:467.)
#   return torch.floor_divide(self, other)
# Inferencing Samples:  60% 6/10 [14:11<09:26, 141.66s/ Batches]
